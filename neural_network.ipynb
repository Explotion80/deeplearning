# %% [markdown]
# <a href="https://colab.research.google.com/github/Explotion80/deeplearning/blob/master/neural_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Implementacja sieci neuronowej

# %%
import numpy as np

np.random.seed(0)

X = np.array([[1.0, 0.7]])
y_true = np.array([1.80])

# %%
def init_parameters(n_x, n_h, n_y):
    W1 = np.random.randn(n_h, n_x)
    W2 = np.random.randn(n_h, n_y)
    return W1, W2

def forward_prop(X, W1, W2):
    # propagacja w przód
    H = np.dot(X, W1)
    y_pred = np.dot(H, W2)
    return H, y_pred

def calculate_error(y_true, y_pred):
    return y_pred - y_true

    # propagacja wsteczna
def backprop(X, W1, W2, learning_rate=0.01, iters=1000, precision=0.0000001):

    H, y_pred = forward_prop(X, W1, W2)

    for i in range(iters):
        error = calculate_error(y_true, y_pred)
        W2 = W2 - learning_rate * error * H.T
        W1 = W1 - learning_rate * error * X.T * W2.T

        _, y_pred = forward_prop(X, W1, W2)

        print('Iter {}, y_pred: {}, error: {}' .format(i, y_pred[0][0], calculate_error(y_true, y_pred[0][0])))

        if abs(error) < precision:
         break

    return W1, W2 

def predict(X, W1, W2):
  _, y_pred = forward_prop(X, W1, W2)
  return y_pred

def build_model():

  # inicjalizacja wag
  W1, W2 = init_parameters(2, 2, 1)

  # propagacja wsteczna
  W1, W2 = backprop(X, W1, W2)

  model = {'W1': W1, 'W2': W2}

  return model

# %%
build_model()
# Out:
# Iter 0, y_pred: 0.38313465407904357, error: [-1.41686535]
# Iter 1, y_pred: 0.43991648380240245, error: [-1.36008352]
# Iter 2, y_pred: 0.4947167392317271, error: [-1.30528326]
# Iter 3, y_pred: 0.5475879726886648, error: [-1.25241203]
# Iter 4, y_pred: 0.5985817102047383, error: [-1.20141829]
# Iter 5, y_pred: 0.6477485793213775, error: [-1.15225142]
# Iter 6, y_pred: 0.6951384067781403, error: [-1.10486159]
# Iter 7, y_pred: 0.7408002906600782, error: [-1.05919971]
# Iter 8, y_pred: 0.7847826510644074, error: [-1.01521735]
# Iter 9, y_pred: 0.827133262882084, error: [-0.97286674]
# Iter 10, y_pred: 0.8678992738671522, error: [-0.93210073]
# Iter 11, y_pred: 0.9071272107821917, error: [-0.89287279]
# Iter 12, y_pred: 0.944862976058789, error: [-0.85513702]
# Iter 13, y_pred: 0.9811518370949757, error: [-0.81884816]
# Iter 14, y_pred: 1.01603841002472, error: [-0.78396159]
# Iter 15, y_pred: 1.0495666395356253, error: [-0.75043336]
# ...
